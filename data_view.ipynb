# %%
import pandas as pd

# Đường dẫn đến file ma trận tương tác
file_path = 'output/interaction_matrix.pkl'

# Đọc file bằng Pandas
matrix = pd.read_pickle(file_path)

print("Kiểu dữ liệu gốc:", type(matrix))
print(f"Kích thước ma trận: {matrix.shape[0]} sản phẩm × {matrix.shape[1]} người dùng")

# MẸO XỊN: Cắt một "góc" nhỏ (5 sản phẩm đầu tiên và 8 người dùng đầu tiên) để quan sát
matrix.iloc[:5, :8]
# Out:
# Kiểu dữ liệu: <class 'pandas.DataFrame'>
# Nội dung dữ liệu:
#             AE2E632GMYL5U2ESNXOX5UT5D34A  AE2OFVZSIE6KSBAPG6GMKCER35LA  \
# product_id
# B002PD61Y4                           0.0                           0.0
# B008FWZGSG                           0.0                           0.0
# B00NH11KIK                           0.0                           0.0
# B00NH11PEY                           0.0                           0.0
# B0141EZMAI                           0.0                           0.0
# ...                                  ...                           ...
# B0B9BD2YL4                           0.0                           0.0
# B0B9BXKBC7                           0.0                           0.0
# B0BDRVFDKP                           0.0                           0.0
# B0BFWGBX61                           0.0                           0.0
# B0BMXMLSMM                           0.0                           0.0
#
# ...

# %%
import pandas as pd

# Đường dẫn đến file mapping
file_path = 'output/item_mapping.pkl'

# Pandas vẫn đọc file dict .pkl cực mượt!
mapping = pd.read_pickle(file_path)

print("Kiểu dữ liệu gốc:", type(mapping))
print(f"Tổng số sản phẩm có trong dữ liệu: {len(mapping)}")

# MẸO JUPYTER: Ép kiểu dict sang Pandas Series để nó render thành bảng HTML cực đẹp
view_df = pd.Series(mapping).to_frame(name="Tên Sản Phẩm")
view_df.index.name = "Mã Sản Phẩm (ID)"

# Xem nhanh 5 sản phẩm đầu tiên
view_df.head()
# Out:
# Kiểu dữ liệu: <class 'dict'>
# Nội dung dữ liệu:
# ...

# %%
import pandas as pd

# Đường dẫn đến file
file_path = 'output/similarity_matrix.pkl'

# Đọc file pkl siêu nhanh bằng Pandas (thay vì dùng thư viện pickle gốc)
data = pd.read_pickle(file_path)

# Kiểm tra kích thước ma trận
print(f"Kích thước ma trận: {data.shape}")

# Hiển thị 5 dòng đầu tiên (Không dùng print để Jupyter render bảng HTML đẹp mắt)
data.head()
